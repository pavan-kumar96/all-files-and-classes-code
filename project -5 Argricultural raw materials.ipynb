# %%
import pandas as pd

# %%
data = pd.read_csv('agricultural_raw_material.csv')

# %%
data.sample(10)
# Out:
#       Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 325  May-17          1,019.95                      2.91%    1,112.50
# 330  Oct-17               NaN                        NaN         989
# 158  Jun-03            680.28                      7.47%         279
# 13   May-91            371.88                      1.66%         226
# 61   May-95            516.49                     -0.73%         410
# 234  Oct-09            743.59                      7.62%         470
# 255  Jul-11          1,362.27                     -1.69%    1,121.00
# 181  May-05            543.49                     -0.04%      446.25
# 177  Jan-05            556.94                      1.76%       429.5
# 343  Nov-18               NaN                        NaN         NaN
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 325                6.56%          1.95                 1.56%        1,433.47
# ...

# %%
data = data.replace('%','', regex = True)
data = data.replace('-','', regex = True)
data = data.replace(',','', regex = True)
data= data.replace('', np.nan)
data = data.replace('May90',np.nan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
# Month                           361 non-null object
# Coarse wool Price               327 non-null object
# Coarse wool price % Change      326 non-null object
# Copra Price                     339 non-null object
# Copra price % Change            338 non-null object
# Cotton Price                    361 non-null float64
# Cotton price % Change           360 non-null object
# Fine wool Price                 327 non-null object
# Fine wool price % Change        326 non-null object
# Hard log Price                  361 non-null float64
# Hard log price % Change         360 non-null object
# Hard sawnwood Price             327 non-null float64
# Hard sawnwood price % Change    326 non-null object
# Hide Price                      327 non-null float64
# Hide price % change             326 non-null object
# Plywood Price                   361 non-null float64
# ...

# %%
data = data.dropna()

# %%
data.columns
# Out:
# Index(['Month', 'Coarse wool Price', 'Coarse wool price % Change',
#        'Copra Price', 'Copra price % Change', 'Cotton Price',
#        'Cotton price % Change', 'Fine wool Price', 'Fine wool price % Change',
#        'Hard log Price', 'Hard log price % Change', 'Hard sawnwood Price',
#        'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
#        'Plywood Price', 'Plywood price % Change', 'Rubber Price',
#        'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
#        'Soft sawnwood Price', 'Soft sawnwood price % Change',
#        'Wood pulp Price', 'Wood pulp price % Change'],
#       dtype='object')

# %%
cat_data = data.select_dtypes(include= ['O'])

# %%
cat_data = cat_data.drop(columns = ['Month']).astype('float')

# %%
import seaborn as sns

# %%
data[cat_data.columns] = cat_data

# %%
columns = list(data.columns)

# %%
for i in range(0,12,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for value in range(0,24,2):
    print(value)
#     print(columns[value])
    print(data[[columns[value],columns[value+1]].plot(figsize=(11, 9), subplots=True, linewidth=1)
# Out:
#   File "<ipython-input-128-59962e761e55>", line 5
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
axes = data[["Coarse wool Price", "Coarse wool price % Change"]].plot(figsize=(11, 9), subplots=True, linewidth=1)
