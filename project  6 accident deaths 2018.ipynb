# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
file = pd.read_excel('datafile.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
file
# Out:
#    Sl. No.                                              Cause  \
# 0        1                                          Air Crash
# 1        2                                     Ship Accidents
# 2        3                      Collapse of Structure (Total)
# 3        3  3.1 Collapse of Dwelling House/Residential Bui...
# 4        3      3.2 Collapse of Official/ Commercial Building
# ..     ...                                                ...
# 57      19                                        Suffocation
# 58      20                                      Drug Overdose
# 59      21                            Other than above Causes
# 60      22                                   Causes Not Known
# 61   Total                                              Total
#
#     Below 14 years - Male  Below 14 years - Female  \
# 0                       0                        0
# 1                       0                        0
# 2                     101                       77
# ...

# %% [markdown]
# ### Reading  or Describing the data and finding the useful insights

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 31 columns):
# Sl. No.                                        62 non-null object
# Cause                                          62 non-null object
# Below 14 years - Male                          62 non-null int64
# Below 14 years - Female                        62 non-null int64
# Below 14 years - Transgender                   62 non-null int64
# Below 14 years - Total                         62 non-null int64
# 14 and Above - Below 18 years - Male           62 non-null int64
# 14 and Above - Below 18 years - Female         62 non-null int64
# 14 and Above - Below 18 years - Transgender    62 non-null int64
# 14 and Above - Below 18 years - Total          62 non-null int64
# 18 and Above - Below 30 years - Male           62 non-null int64
# 18 and Above - Below 30 years - Female         62 non-null int64
# 18 and Above - Below 30 years - Transgender    62 non-null int64
# ...

# %%
file.describe()
# Out:
#        Below 14 years - Male  Below 14 years - Female  \
# count              62.000000                62.000000
# mean              490.822581               242.048387
# std              1528.400691               740.474425
# min                 0.000000                 0.000000
# 25%                 3.000000                 2.500000
# 50%                33.500000                17.500000
# 75%               264.250000               161.000000
# max             10917.000000              5488.000000
#
#        Below 14 years - Transgender  Below 14 years - Total  \
# count                     62.000000               62.000000
# mean                       0.096774              732.967742
# std                        0.469030             2263.148206
# min                        0.000000                0.000000
# 25%                        0.000000                7.250000
# 50%                        0.000000               53.500000
# ...

# %%
file.head(3)
# Out:
#   Sl. No.                          Cause  Below 14 years - Male  \
# 0       1                      Air Crash                      0
# 1       2                 Ship Accidents                      0
# 2       3  Collapse of Structure (Total)                    101
#
#    Below 14 years - Female  Below 14 years - Transgender  \
# 0                        0                             0
# 1                        0                             0
# 2                       77                             0
#
#    Below 14 years - Total  14 and Above - Below 18 years - Male  \
# 0                       0                                     0
# 1                       0                                     0
# 2                     178                                    96
#
#    14 and Above - Below 18 years - Female  \
# 0                                       0
# 1                                       0
# 2                                      49
#
# ...

# %% [markdown]
# ### Finding if there is any missing values

# %%
file.isna().sum()
# Out:
# Sl. No.                                        0
# Cause                                          0
# Below 14 years - Male                          0
# Below 14 years - Female                        0
# Below 14 years - Transgender                   0
# Below 14 years - Total                         0
# 14 and Above - Below 18 years - Male           0
# 14 and Above - Below 18 years - Female         0
# 14 and Above - Below 18 years - Transgender    0
# 14 and Above - Below 18 years - Total          0
# 18 and Above - Below 30 years - Male           0
# 18 and Above - Below 30 years - Female         0
# 18 and Above - Below 30 years - Transgender    0
# 18 and Above - Below 30 years - Total          0
# 30 and Above - Below 45 years - Male           0
# 30 and Above - Below 45 years - Female         0
# 30 and Above - Below 45 years - Transgender    0
# 30 and Above - Below 45 years - Total          0
# 45 and Above - Below 60 years - Male           0
# ...

# %%
# we are removing the last row beacuse it is total columns
file = file[:-1]

# %% [markdown]
# ### Finding the unique caused for death

# %%
file.Cause.value_counts()
# Out:
# 18.3.2 Other Poisonous Gases                            1
# Deaths Due to Consumption of Illicit/Spurious Liquor    1
# 7.3 Fall into Manhole                                   1
# 18.3 Poisonous Gases (Total)                            1
# Killed / Injured by Animals                             1
#                                                        ..
# 7.5 Fall into Borewell                                  1
# 14.2 Heart Attack                                       1
# 4.3 Other Cases                                         1
# 9.1 Electrical Short circuit                            1
# Electrocution                                           1
# Name: Cause, Length: 61, dtype: int64

# %% [markdown]
# #### visulaization depending upon the age group

# %%
file.columns
# Out:
# Index(['Sl. No.', 'Cause', 'Below 14 years - Male', 'Below 14 years - Female',
#        'Below 14 years - Transgender', 'Below 14 years - Total',
#        '14 and Above - Below 18 years - Male',
#        '14 and Above - Below 18 years - Female',
#        '14 and Above - Below 18 years - Transgender',
#        '14 and Above - Below 18 years - Total',
#        '18 and Above - Below 30 years - Male',
#        '18 and Above - Below 30 years - Female',
#        '18 and Above - Below 30 years - Transgender',
#        '18 and Above - Below 30 years - Total',
#        '30 and Above - Below 45 years - Male',
#        '30 and Above - Below 45 years - Female',
#        '30 and Above - Below 45 years - Transgender',
#        '30 and Above - Below 45 years - Total',
#        '45 and Above - Below 60 years - Male',
#        '45 and Above - Below 60 years - Female',
#        '45 and Above - Below 60 years - Transgender',
#        '45 and Above - Below 60 years - Total', '60 years & Above - Male',
# ...

# %%
file[['Below 14 years - Total', '14 and Above - Below 18 years - Total','18 and Above - Below 30 years - Total','30 and Above - Below 45 years - Total','45 and Above - Below 60 years - Total', '60 years & Above - Total']].plot()

# %%
file[['Below 14 years - Total', '14 and Above - Below 18 years - Total','18 and Above - Below 30 years - Total','30 and Above - Below 45 years - Total','45 and Above - Below 60 years - Total', '60 years & Above - Total']].value_counts().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-1acc0cbb1c20> in <module>
# ----> 1 file[['Below 14 years - Total', '14 and Above - Below 18 years - Total','18 and Above - Below 30 years - Total','30 and Above - Below 45 years - Total','45 and Above - Below 60 years - Total', '60 years & Above - Total']].value_counts().plot.bar()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
import pandas as pd

# %%
import pandas as pd
import xml.etree.ElementTree as et


    
xtree = et.parse('xmldata.xml')
xroot = xtree.getroot()
rows = []

for node in xroot: 
    res = []
    res.append(node.attrib.get(df_cols[0]))
    for el in df_cols[1:]: 
        if node is not None and node.find(el) is not None:
            res.append(node.find(el).text)
        else: 
            res.append(None)
    rows.append({df_cols[i]: res[i] 
                 for i, _ in enumerate(df_cols)})

out_df = pd.DataFrame(rows, columns=df_cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-afd31ada3fbf> in <module>
#      10 for node in xroot:
#      11     res = []
# ---> 12     res.append(node.attrib.get(df_cols[0]))
#      13     for el in df_cols[1:]:
#      14         if node is not None and node.find(el) is not None:
#
# NameError: name 'df_cols' is not defined
