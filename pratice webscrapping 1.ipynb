# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas

# %%
from bs4 import BeautifulSoup
 
import requests
import sys
 
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text)
tr = soup.findChildren("tr")
tr = iter(tr)
next(tr)
 
for movie in tr:
    title = movie.find('td', {'class': 'titleColumn'} ).find('a').contents[0]
    year = movie.find('td', {'class': 'titleColumn'} ).find('span', {'class': 'secondaryInfo'}).contents[0]
    rating = movie.find('td', {'class': 'ratingColumn imdbRating'} ).find('strong').contents[0]
    row = title + ' - ' + year + ' ' + ' ' + rating
 
print(row)
# Out:
# Chak De! India - (2007)  8.0

# %%
# url = "https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_0_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_0_3_na_na_na&as-pos=0&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=37a3aa11-3568-49c4-be60-4f53fa5ad65f&as-searchtext=lap"
# response = requests.get(url)

# soup = bs(response.content,"html.parser")
# cards = soup.find_all("div",attrs ={"class":"bhgxx22"})
# for card in cards:
#     mobile_name = (card.find("div",attrs = {"class":"_3wU53n"}))
#     print(mobile_name)
#     mobile_tex = mobile_name.text
    
#     price_value = card.find("div",attrs = {"class":"_2rQ-NK"})
#     price_text = price_value.text
  
#     rating_mob = card.find("div",attrs = {"class":"niH0FQ"})
#     rating_text = rating_mob.text
# print("{}{}{}".format(mobile_name,price_text,rating_text))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# ...

# %%
# for card in cards:

#     title_div = card.find("div",attrs={"class":"_3wU53n"})
#     title_text = title_div.text

#     price_div = card.find("div",attrs={"class":"_2rQ-NK"})
#     price_text = price_div.text

#     rating_div = card.find("div",attrs = {"class":"hGSR34"})
#     rating_text = rating_div.text


#     detail_page_link = card.find("a",attrs = {"class":"_31qSD5"})
#     home_url = "https://www.flipkart.com"

#     mob_page_url = home_url+detail_page_link.get("href")


#     response3 = requests.get(mob_page_url)


#     soup3 = BeautifulSoup(response3.content,"html.parser")

#     seller_name = soup3.find("div",attrs = {"id":"sellerName"})
#     seller_text = seller_name.text

#     print("{} {} {} {}".format(title_text,price_text,rating_text,seller_text))

# %%
# url =  "https://www.amazon.in/s?k=phones&ref=nb_sb_noss_2"
# response2 = requests.get(url)
# soup2 = bs(response2.content,"html.parser")
# cards = soup2.find_all("div",attrs = {"class":"_1UoZlX"})

# for card in cards:

#     title_div = card.find("div",attrs={"class":"_3wU53n"})
#     title_text = title_div.text

#     price_div = card.find("div",attrs={"class":"_2rQ-NK"})
#     price_text = price_div.text

#     rating_div = card.find("div",attrs = {"class":"hGSR34"})
#     rating_text = rating_div.text
# print("{} {} {}".format(title_text,price_text,rating_text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7fce05018aed> in <module>
#      14     rating_div = card.find("div",attrs = {"class":"hGSR34"})
#      15     rating_text = rating_div.text
# ---> 16 print("{} {} {}".format(title_text,price_text,rating_text))
#
# NameError: name 'title_text' is not defined

# %%
import requests as rp
from bs4 import BeautifulSoup as bs
import random
import urllib.request

# %%
url = "https://media.istockphoto.com/photos/hindu-god-krishna-picture-id175454330?k=6&m=175454330&s=612x612&w=0&h=O11Hv-bTXTlVX0kMktLQOTeh-gG1huf_RWOoeKTodHQ="

response = rp.get(url)
fp = open("img22.jpg","wb")
fp.write(response.content)
fp.close()

# %%
url = "https://www.istockphoto.com/in/photos/lord-krishna?sort=mostpopular&mediatype=photography&phrase=lord%20krishna#close"
response = rp.get(url)
soup = bs(response.content, "html.parser")
images = soup.find_all("img",attrs = {"class":"gallery-asset__thumb gallery-mosaic-asset__thumb"})

for image in images:
    src = image.get("src")
    soup1 = rp.get(src)
    
    img = random.randrange(1,500)
    name = "image"+ str(img)+".jpg"
    print(name)
    fp = open(name,"wb")
    content = fp.write(soup1.content)
#     #     print(content)
    fp.close()
    
#     urllib.request.urlretrieve(name,src)
#     print("loop Break")
# Out:
# image470.jpg
# image226.jpg
# image36.jpg
# image223.jpg
# image461.jpg
# image154.jpg
# image76.jpg
# image300.jpg
# image71.jpg
# image304.jpg
# image211.jpg
# image21.jpg
# image148.jpg
# image132.jpg
# image148.jpg
# image479.jpg
# image438.jpg
# image221.jpg
# image236.jpg
# image59.jpg
# image321.jpg
# image48.jpg
# image169.jpg
# image244.jpg
# image46.jpg
# image211.jpg
# image426.jpg
# image397.jpg
# image13.jpg
# image419.jpg
# image275.jpg
# image77.jpg
# image111.jpg
# image37.jpg
# image127.jpg
# image4.jpg
# image64.jpg
# image211.jpg
# image270.jpg
# image301.jpg
# image388.jpg
# image419.jpg
# image81.jpg
# image463.jpg
# image174.jpg
# image386.jpg
# image225.jpg
# image322.jpg
# image109.jpg
# image108.jpg
# image89.jpg
# image68.jpg
# image273.jpg
# image427.jpg
# image19.jpg
# image39.jpg
# image160.jpg
# image436.jpg
# image53.jpg
# image194.jpg

# %%
url= "https://www.istockphoto.com/in/photo/offerings-at-parthasarathy-temple-chennai-gm490938632-75487995"
response = rp.get(url)
fp = open("img1.jpg","wb")
fp.write(response.content)
fp.close()

# %%
import random
import requests as rp
from bs4 import BeautifulSoup as bs

# %%
url = "https://www.gettyimages.in/photos/lord-krishna?sort=mostpopular&mediatype=photography&phrase=lord%20krishna"
resp1 = rp.get(url)
soup2 = bs(resp1.content,"html.parser")
photos = soup2.find_all("img",attrs = {"class":"gallery-asset__thumb"})
for _ in range(4):

    detail_page_link = soup2.find("a",attrs = {"class":"search-pagination__button"})
    home_url ="https://www.gettyimages.in"
    mob_page_url = home_url+detail_page_link.get("href")
    response3 = rp.get(mob_page_url)
    soup3 = bs(response3.content,"html.parser")
    print(soup3)
    
    photos = soup3.find_all("img",attrs = {"class":"gallery-asset__thumb"})
    print(photos)
    for photo in photos:
        src1 = photo.get("src")
        print(src1)
        resp3 = rp.get(src1)
        image_name = random.randrange(1500,1800)
        photo_name = "photo"+ str(image_name)+".jpg"
        fp1 = open(photo_name,"wb")
        fp1.write(resp3.content)
        fp1.close()
# Out:
# <!DOCTYPE html>
# <html class="en-gb no-js" lang="en-gb" prefix="og: http://ogp.me/ns#"><head><link as="style" crossorigin="" href="https://fonts.googleapis.com/css?family=Lato:400,400i,700,700i&amp;subset=latin-ext" rel="preload"/><link href="https://fonts.googleapis.com/css?family=Lato:400,400i,700,700i&amp;subset=latin-ext" rel="stylesheet"/><link href="/landing/assets/packs/css/getty-31b8cffb.css" media="all" rel="stylesheet"/><script>window.renderStart = new Date().getTime();</script><title>Royalty Free Stock Photos, Illustrations, Vector Art and Video Clips - Getty Images</title><meta charset="utf-8"/><meta content="authenticity_token" name="csrf-param"/>
# ...

# %%
for i in range(1,4):
    url = "https://www.istockphoto.com/in/photos/lord-krishna?mediatype=photography&page="+str(i)+"&phrase=lord%20krishna&sort=mostpopular#close"
    resp1 = rp.get(url)

    soup2 = bs(resp1.content,"html.parser")
    photos = soup2.find_all("img", attrs = {"class":"gallery-asset__thumb"})
#     print(photos)

    for photo in photos:
        src1 = photo.get("src")
#         print(src1)
        resp4 = rp.get(src1)
        image_name = random.randrange(1500,2000)
        photo_name = "photo"+ str(image_name)+".jpg"
        fp1 = open(photo_name,"wb")
        fp1.write(resp4.content)
        fp1.close()

# %%
headers = {"User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Mobile Safari/537.36","age": "186",

"cache-control": "public, max-age=3600",
"cf-bgj": "minify",
"cf-cache-status": "HIT",
"cf-polished": "origSize=141345",
"cf-ray": "56343ebd7ea1c327-SIN",
"content-encoding": "br",
"content-type": "application/javascript",


"server": "cloudflare",
"status": "304",
"vary": "Accept-Encoding",
"via": "1.1 c62f6c9a9fdf2356a904a1b156a05fe1.cloudfront.net (CloudFront)"
,"x-amz-cf-id": "_NWVqendYJ2VEmSTU_rbC2eMsRlncJ0BisM8JENfIlCbOrRaM4QibQ=="
,"x-amz-cf-pop": "EWR52-C1"
,"x-amz-replication-status": "COMPLETED"
,"x-amz-version-id": ".0OZ2saaEE26VfTco2nYzKYvk7x8dePM"
,"x-cache": "Hit from cloudfront"}
url = "https://www.pexels.com/search/4k%20wallpaper/"
res = rp.get(url,"headers" = "headers")
print(res)
# Out:
#   File "<ipython-input-7-7630d6d2fc11>", line 22
#     res = rp.get(url,"headers" = "headers")
#                     ^
# SyntaxError: keyword can't be an expression
